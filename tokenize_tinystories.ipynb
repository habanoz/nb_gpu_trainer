# %%
# !python src/nbtr/cli_train_tokenizer.py
# Out:
# usage: cli_train_tokenizer.py [-h] --ds_repo_id DS_REPO_ID --repo_id REPO_ID
#                               [--out_dir OUT_DIR] [--vocab_exp VOCAB_EXP]
#                               [--ratio RATIO]
# cli_train_tokenizer.py: error: the following arguments are required: --ds_repo_id, --repo_id

# %%
# !python src/nbtr/cli_train_tokenizer.py --ds_repo_id roneneldan/TinyStories --repo_id tiny-stories-tokenizer-8k --out_dir tiny-stories-tokenizer-8k --vocab_exp 13
# Out:
# Selected train dataset size 2119719, selected validation dataset size 0
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /tmp/tmpk10lwe59
#   input_format:
#   model_prefix: tiny-stories-tokenizer-8k/tokenizer
#   model_type: BPE
#   vocab_size: 8192
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
# ...

# %%
# !python src/nbtr/cli_generate_data.py
# Out:
# usage: cli_generate_data.py [-h] --repo_id REPO_ID --ds_repo_id DS_REPO_ID
#                             [--data_dir DATA_DIR]
# cli_generate_data.py: error: the following arguments are required: --repo_id, --ds_repo_id

# %%
# !python src/nbtr/cli_generate_data.py --ds_repo_id roneneldan/TinyStories --repo_id tiny-stories-tokenizer-8k --data_dir tiny-stories-vocab-8k
# Out:
# Renaming column 'validation' to 'val'!
# Generating tokens!
# ...
# tokenizing the splits: 100%|█████| 21990/21990 [00:02<00:00, 8488.35 examples/s]
# Split train, token count: 454763070
# Saving split 'train', docs: 2119719, tokens: 454763070 in 1048576 batches.
# writing tiny-stories-vocab-8k/train.bin: 100%|█| 1048576/1048576 [27:52<00:00, 6
# Saved 'train' tokens.
# Split val, token count: 4576423
# Saving split 'val', docs: 21990, tokens: 4576423 in 1024 batches.
# writing tiny-stories-vocab-8k/val.bin: 100%|█| 1024/1024 [00:01<00:00, 625.19it/
# Saved 'val' tokens.
# Done!
